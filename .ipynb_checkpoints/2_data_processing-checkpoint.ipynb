# %% [markdown]
# # Import Libraries

# %%
import os

import pandas as pd
import numpy as np

from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from wordcloud import WordCloud

from translate import Translator

# functions which is special for this notebook
from string_operation import StringOperation

# %% [markdown]
# If the text is in **Indonesian**, a library called **Sastrawi** can be used.

# %% [markdown]
# # Read Dataset

# %%
input_path = os.path.join('dataset', 'scrapping_result.csv')
df_scrapping = pd.read_csv(input_path)
print(df_scrapping.shape)

display(df_scrapping)
# Out:
# (219, 5)
#      page number  rank               domain  \
# 0              1     1        www.linux.com
# 1              1     2     en.wikipedia.org
# 2              1     3   www.techtarget.com
# 3              1     4        www.linux.org
# 4              1     5       www.guru99.com
# ..           ...   ...                  ...
# 214           22   215        polindo.ac.id
# 215           22   216       www.jenkins.io
# 216           22   217  www.linux-india.org
# 217           22   218     www.anaconda.com
# 218           22   219        fossbytes.com
#
#                                                    url  \
# 0                 https://www.linux.com/what-is-linux/
# 1                  https://en.wikipedia.org/wiki/Linux
# 2    https://www.techtarget.com/searchdatacenter/de...
# 3                               https://www.linux.org/
# 4       https://www.guru99.com/introduction-linux.html
# ..                                                 ...
# 214  https://polindo.ac.id/applicatlon/akademi/apa-...
# 215  https://www.jenkins.io/doc/book/installing/linux/
# 216  https://www.linux-india.org/best-of-technical-...
# 217     https://www.anaconda.com/products/distribution
# 218  https://fossbytes.com/ubuntu-linux-is-the-most...
#
#                                                  title
# 0                           What is Linux? - Linux.com
# 1                                    Linux - Wikipedia
# 2     What is the Linux operating system? - TechTarget
# 3                                            Linux.org
# 4    What is Linux Operating System? Introduction t...
# ..                                                 ...
# 214  Apa yang dimaksud sistem operasi linux - Polit...
# 215                                    Linux - Jenkins
# 216  Linux Support – Linux C Graphic Libraries - Li...
# 217                              Anaconda Distribution
# 218  Ubuntu Linux is the Most Popular Operating Sys...
#
# [219 rows x 5 columns]

# %% [markdown]
# # Simple Profiling

# %% [markdown]
# there will be no visualization

# %%
# check profile and missing value
print(df_scrapping.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   page number  219 non-null    int64
#  1   rank         219 non-null    int64
#  2   domain       219 non-null    object
#  3   url          219 non-null    object
#  4   title        219 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 8.7+ KB
# None

# %% [markdown]
# there is no missing value

# %%
# check domain website that is shown more than one
print('unique domain website:', df_scrapping['domain'].nunique())

webdomain_count = df_scrapping['domain'].value_counts().to_frame()
webdomain_count.columns = ['count']
webdomain_count.index.name = 'domain web'
webdomain_count = webdomain_count[webdomain_count['count']>1]

print('n website domain with more than one data:', webdomain_count.shape[0])
display(webdomain_count)
# Out:
# unique domain website: 187
# n website domain with more than one data: 31
#                        count
# domain web
# www.codecademy.com         3
# crln.acrl.org              2
# www.elprocus.com           2
# www.slackware.com          2
# www.ibm.com                2
# rockylinux.org             2
# archlinux.org              2
# www.scaler.com             2
# xubuntu.org                2
# www.centerklik.com         2
# www.globenewswire.com      2
# www.section.io             2
# www.toppr.com              2
# lemelson.mit.edu           2
# www.vmware.com             2
# www.cio.com                2
# www.stackscale.com         2
# www.ijser.org              2
# linuxiac.com               2
# www.webasha.com            2
# csit.ust.edu.sd            2
# www.nwkings.com            2
# nielharper.com             2
# www.kali.org               2
# www.theregister.com        2
# www.computerreach.org      2
# mindmajix.com              2
# www.hostinger.com          2
# www.gnu.org                2
# www.codeweavers.com        2
# news.uhb.ac.id             2

# %%
# website domain more than one data with respective content rank and page
wdomain_count_wrank = (df_scrapping.groupby(['domain'])
      .agg({'rank': lambda x: x.tolist(), 'page number': lambda x: x.tolist()})
      )
wdomain_count_wrank.index.name = 'domain web'

# merge data with domain count
wdomain_merge = webdomain_count.merge(wdomain_count_wrank, on='domain web',
                                     how='left')
# sort values by rank
wdomain_merge.sort_values(by=['rank'], inplace=True)
display(wdomain_merge)

print(f'''the number domain web with more than 1 content is {wdomain_merge.index[0]}\
with rank {wdomain_merge.iloc[0, 1]} in page {wdomain_merge.iloc[0, 2]}''')
# Out:
#                        count           rank  page number
# domain web
# www.gnu.org                2       [27, 30]       [3, 4]
# mindmajix.com              2       [31, 40]       [4, 5]
# www.elprocus.com           2       [33, 42]       [4, 5]
# www.ibm.com                2       [35, 41]       [4, 5]
# rockylinux.org             2       [36, 54]       [4, 6]
# archlinux.org              2       [38, 50]       [4, 6]
# www.scaler.com             2       [39, 46]       [4, 5]
# www.globenewswire.com      2       [57, 63]       [6, 7]
# lemelson.mit.edu           2       [59, 60]       [6, 7]
# www.toppr.com              2       [78, 81]       [8, 9]
# www.codecademy.com         3  [87, 99, 109]  [9, 10, 11]
# www.cio.com                2       [88, 90]      [9, 10]
# www.stackscale.com         2       [89, 96]      [9, 10]
# www.ijser.org              2      [91, 107]     [10, 11]
# www.webasha.com            2     [103, 111]     [11, 12]
# csit.ust.edu.sd            2     [105, 119]     [11, 12]
# www.nwkings.com            2     [106, 114]     [11, 12]
# www.kali.org               2     [115, 123]     [12, 13]
# www.computerreach.org      2     [120, 137]     [13, 14]
# www.section.io             2     [122, 132]     [13, 14]
# www.hostinger.com          2     [124, 139]     [13, 14]
# www.theregister.com        2     [125, 142]     [13, 15]
# nielharper.com             2     [128, 141]     [13, 15]
# linuxiac.com               2     [140, 150]     [15, 16]
# crln.acrl.org              2     [149, 154]     [15, 16]
# www.centerklik.com         2     [179, 188]     [18, 19]
# xubuntu.org                2     [181, 190]     [19, 20]
# www.slackware.com          2     [185, 191]     [19, 20]
# www.vmware.com             2     [189, 193]     [19, 20]
# news.uhb.ac.id             2     [199, 203]     [20, 21]
# www.codeweavers.com        2     [209, 210]     [21, 22]
# the number domain web with more than 1 content is www.gnu.orgwith rank [27, 30] in page [3, 4]

# %%
# see wordcloud

long_string = ','.join(list(df_scrapping['title'].values))# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue',
                     width=800, height=400)# Generate a word cloud
wordcloud.generate(long_string)# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %% [markdown]
# # Preprocess

# %% [markdown]
# text preprocessing to standardize words

# %%
df_preprocess = df_scrapping.copy()

# remove nonalphabetic data
df_preprocess['clean_title'] = StringOperation.remove_nonalphabet(df_preprocess['title'])
# remove stopwords
df_preprocess['clean_title'] = StringOperation.remove_stopwords(df_preprocess['clean_title'], stopwords.words('english'))
# word stemming
df_preprocess['clean_title'] = StringOperation.word_stemming(df_preprocess['clean_title'], PorterStemmer(), word_tokenize)

display(df_preprocess)
# Out:
#     page number  rank                domain  \
# 0             1     1           itsfoss.com
# 1             1     2         www.zdnet.com
# 2             1     3    www.debugpoint.com
# 3             1     4       www.youtube.com
# 4             1     5            ubuntu.com
# ..          ...   ...                   ...
# 94           10    95        www.edureka.co
# 95           10    96  www.computer-pdf.com
# 96           10    97             aktif.net
# 97           10    98   www.seeedstudio.com
# 98           10    99             maker.pro
#
#                                                   url  \
# 0           https://itsfoss.com/best-linux-beginners/
# 1   https://www.zdnet.com/article/best-linux-deskt...
# 2   https://www.debugpoint.com/linux-distro-beginn...
# 3     https://www.youtube.com/watch%3Fv%3DROjZy1WbCIA
# 4   https://ubuntu.com/tutorials/command-line-for-...
# ..                                                ...
# 94  https://www.edureka.co/blog/interview-question...
# 95  https://www.computer-pdf.com/operating-system/...
# 96  https://aktif.net/en/simple-linux-commands-for...
# 97  https://www.seeedstudio.com/blog/2021/01/20/be...
# 98  https://maker.pro/linux/tutorial/basic-linux-c...
#
#                                                 title  \
# 0   Best Linux Distributions That are Most Suitabl...
# 1   The 5 best Linux distros for beginners in 2022...
# 2   Top 10 Linux Distros for Beginners in 2022 [Co...
# 3   Linux Operating System - Crash Course for Begi...
# 4       The Linux command line for beginners - Ubuntu
# ..                                                ...
# 94  Top 50 Linux Interview Questions and Answers i...
# 95  [PDF] Linux Fundamentals free tutorial for Beg...
# 96        Simple Linux Commands for Beginners – Aktif
# 97  Embedded Linux: A Beginner's Guide - Latest Op...
# 98     Basic Linux Commands for Beginners - Maker Pro
#
#                                        clean_title
# 0              best linux distribut suitabl beginn
# 1                   best linux distro beginn zdnet
# 2                   top linux distro beginn compar
# 3      linux oper system crash cours beginn youtub
# 4                 linux command line beginn ubuntu
# ..                                             ...
# 94     top linux interview question answer edureka
# 95          pdf linux fundament free tutori beginn
# 96                simpl linux command beginn aktif
# 97  embed linux beginn guid latest open tech seeed
# 98            basic linux command beginn maker pro
#
# [99 rows x 6 columns]

# %%
# create model for text data

vectorizer = TfidfVectorizer(tokenizer = word_tokenize)
tfidf_model = vectorizer.fit_transform(df_preprocess['clean_title'])

# %% [markdown]
# # Clustering Section

# %% [markdown]
# clustering process be evaluated using **silhouette score**

# %%
# define range cluster to ve evaluated
max_cluster = int(df_preprocess.shape[0]/2) + 1
cluster_range = range(2,max_cluster)

result_score = {}

for cluster_ in cluster_range:
    km_model = KMeans(n_clusters=cluster_, random_state=42)
    km_model.fit_predict(tfidf_model)
    
    score = silhouette_score(tfidf_model, km_model.labels_, metric='euclidean')
    # Print the score
    print(f'Silhouetter Score for {cluster_}: %.3f' % score)
    
    # save result
    result_score[cluster_] = score
# Out:
# Silhouetter Score for 2: 0.025
# Silhouetter Score for 3: 0.043
# Silhouetter Score for 4: 0.045
# Silhouetter Score for 5: 0.062
# Silhouetter Score for 6: 0.056
# Silhouetter Score for 7: 0.058
# Silhouetter Score for 8: 0.060
# Silhouetter Score for 9: 0.098
# Silhouetter Score for 10: 0.082
# Silhouetter Score for 11: 0.087
# Silhouetter Score for 12: 0.094
# Silhouetter Score for 13: 0.090
# Silhouetter Score for 14: 0.107
# Silhouetter Score for 15: 0.096
# Silhouetter Score for 16: 0.100
# Silhouetter Score for 17: 0.116
# Silhouetter Score for 18: 0.122
# Silhouetter Score for 19: 0.120
# Silhouetter Score for 20: 0.121
# Silhouetter Score for 21: 0.129
# Silhouetter Score for 22: 0.125
# Silhouetter Score for 23: 0.146
# Silhouetter Score for 24: 0.131
# Silhouetter Score for 25: 0.131
# Silhouetter Score for 26: 0.134
# Silhouetter Score for 27: 0.146
# Silhouetter Score for 28: 0.130
# Silhouetter Score for 29: 0.143
# Silhouetter Score for 30: 0.140
# Silhouetter Score for 31: 0.136
# Silhouetter Score for 32: 0.150
# Silhouetter Score for 33: 0.144
# Silhouetter Score for 34: 0.141
# Silhouetter Score for 35: 0.150
# Silhouetter Score for 36: 0.151
# Silhouetter Score for 37: 0.151
# Silhouetter Score for 38: 0.147
# Silhouetter Score for 39: 0.146
# Silhouetter Score for 40: 0.160
# Silhouetter Score for 41: 0.155
# Silhouetter Score for 42: 0.157
# Silhouetter Score for 43: 0.154
# Silhouetter Score for 44: 0.152
# Silhouetter Score for 45: 0.150
# Silhouetter Score for 46: 0.154
# Silhouetter Score for 47: 0.160
# Silhouetter Score for 48: 0.169
# Silhouetter Score for 49: 0.172

# %%
max(list(result_score.values()))
# Out:
# 0.17230085789653216
